# %% [markdown]
# <a href="https://colab.research.google.com/github/Uczas/TechCrush-AI-ML-Course/blob/main/Program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sensor_id = ("ESP32")
temperature = 31.5
pump_active = True
fish_count = input("How many fish are in the pond: ")

print(f"{sensor_id} reports a temp of {temperature}°C, & the pond has {fish_count} fish.")
if pump_active == True:
  print("Water would be changed in 20 minutes times")
# Out:
# How many fish are in the pond: 5000
# ESP32 reports a temp of 31.5°C, & the pond has 5000 fish.
# Water would be changed in 20 minutes times
