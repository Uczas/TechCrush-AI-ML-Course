# %% [markdown]
# <a href="https://colab.research.google.com/github/Uczas/TechCrush-AI-ML-Course/blob/main/Ugbosu-Aquaculture-Sensor-Check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
water_temp_celcius = 28.1
dissolved_oxygrn_mg_l = 5.0
ph_sensor = 6.5

print("--- Ugbosu Aquaculture Sensor Check ----")
if dissolved_oxygrn_mg_l < 5.0:
  print("ALERT: Oxygen level critical! Activating aeration pump.")
elif water_temp_celcius > 30.0:
  print("Warning: Temperature high. Activating cooling system.")
elif ph_sensor < 6.5:
  print("Warning: pH level high. Activating outlet.")
else:
  print("STATUS: Pond environment is optimal.")
# Out:
# --- Ugbosu Aquaculture Sensor Check ----
# STATUS: Pond environment is optimal.
